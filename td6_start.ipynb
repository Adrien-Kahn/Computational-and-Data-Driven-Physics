# %% [markdown]
# ## Tutorial 6: Bayesian inference and single-particle tracking

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read time series t, x(t), y(t) generated with a drift D
data = np.loadtxt('Data/dataM1000d2.5.dat')
data_t = data[:,0]
data_x = data[:,1]
data_y = data[:,2]
data_r = np.linalg.norm(data[:,1:], axis=1)

# Read the number of data point from the data
n = data.shape[0]

# %%
plt.plot(data_x, data_y)
plt.axis("equal")
# Out:
# (-10.088840900000001, 65.7444089, -55.505588100000004, 33.8781921)

# %%
plt.plot(data_t, data_r)

# %%
plt.plot(data_r[1:]**2 / data_t[1:])

# %% [markdown]
# $$ P(\delta x, \delta y, |D, \delta t) = \frac{1}{\sqrt{}}
